# %%
from para_deconv import *
from curve2d_model import *

# %matplotlib inline

# %%
# Invoke the above function to get our data.
NHW = (0, 1, 2)
X_train, y_train, X_val, y_val, X_test, y_test = load_mnist()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape, y_train.dtype)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Train data shape:  (55000, 28, 28)
# Train labels shape:  (55000,) int32
# Validation data shape:  (5000, 28, 28)
# Validation labels shape:  (5000,)
# Test data shape:  (10000, 28, 28)
# Test labels shape:  (10000,)

# %%
plt.figure(1)
plt.subplot(131)
plt.imshow(X_train[1,:,:], cmap='gray')
plt.subplot(132)
plt.imshow(X_train[5,:,:], cmap='gray')
plt.subplot(133)
plt.imshow(X_train[7,:,:], cmap='gray')
plt.show()

# %%
x, y = find_points(X_train[:3,:,:], 200)
x.shape, y.shape
# Out:
# ((3, 200, 2), (3, 200))

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                clip_low=1e-5,clip_high=1,
                lambs=[1e-4,1e-4],drop_rate=0.5,
                reg_lam = 0,num_filter=32,
                section=7, method="Wass", div=0.1, niter=50
                )
model.summary()
# Out:
# Model: "curve2d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              multiple                  544
# _________________________________________________________________
# batch_normalization_v2 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  32832
# _________________________________________________________________
# batch_normalization_v2_1 (Ba multiple                  256
# _________________________________________________________________
# dense (Dense)                multiple                  3212288
# ...

# %%
train(model, X_train, X_val)
# train(model, X_train[y_train==9], X_val[y_val==9])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0405 04:54:48.032461 140241966311232 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Iteration 0: with minibatch training loss = 0.0579
# Iteration 100: with minibatch training loss = 0.0452
# Iteration 200: with minibatch training loss = 0.0471
# Iteration 300: with minibatch training loss = 0.0475
# Iteration 400: with minibatch training loss = 0.0463
# Iteration 500: with minibatch training loss = 0.0454
# Iteration 600: with minibatch training loss = 0.0471
# Iteration 700: with minibatch training loss = 0.0457
# Iteration 800: with minibatch training loss = 0.0444
# Epoch 1, Overall loss = 0.0459
# Iteration 900: with minibatch training loss = 0.048
# Iteration 1000: with minibatch training loss = 0.0467
# ...

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-3,1e-3],drop_rate=0.5,
                num_filter=32,section=7, 
                method="PC"
                )
train(model, X_train, X_val)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0405 11:35:47.336842 139691092272960 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Iteration 0: with minibatch training loss = 0.00109
# Iteration 100: with minibatch training loss = 0.000646
# Iteration 200: with minibatch training loss = 0.000666
# Iteration 300: with minibatch training loss = 0.000644
# Iteration 400: with minibatch training loss = 0.000634
# Iteration 500: with minibatch training loss = 0.000635
# Iteration 600: with minibatch training loss = 0.000648
# Iteration 700: with minibatch training loss = 0.000636
# Iteration 800: with minibatch training loss = 0.000643
# Epoch 1, Overall loss = 0.000655
# Iteration 900: with minibatch training loss = 0.000179
# ...
