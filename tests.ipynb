# %%
from para_deconv import *
from curve2d_model import *

# %matplotlib inline

# %%
NHW = (0, 1, 2)
X_train, y_train, X_val, y_val, X_test, y_test = load_mnist()

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-4,1e-4],section=7, method="Wass")
model.summary()
# Out:
# Model: "curve2d"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              multiple                  544
# _________________________________________________________________
# batch_normalization_v2 (Batc multiple                  128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) multiple                  0
# _________________________________________________________________
# dropout (Dropout)            multiple                  0
# _________________________________________________________________
# conv2d_1 (Conv2D)            multiple                  32832
# _________________________________________________________________
# batch_normalization_v2_1 (Ba multiple                  256
# _________________________________________________________________
# dense (Dense)                multiple                  3212288
# ...

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-4,1e-4],section=7, method="PC")

train(model, X_train[y_train==0], X_val[y_val==0], epochs=5,batch_size=32, reset_lp=0, reset_sp=0)
# Out:
# Iteration 0: with minibatch training loss = 0.00161
# Iteration 100: with minibatch training loss = 0.000194
# Epoch 1, Overall loss = 0.000231
# Iteration 200: with minibatch training loss = 0.000198
# Iteration 300: with minibatch training loss = 0.000201
# Epoch 2, Overall loss = 0.000197
# Iteration 400: with minibatch training loss = 0.000196
# Iteration 500: with minibatch training loss = 0.000197
# Epoch 3, Overall loss = 0.000196
# Iteration 600: with minibatch training loss = 0.0002
# Epoch 4, Overall loss = 0.000196
# Iteration 700: with minibatch training loss = 0.000194
# Iteration 800: with minibatch training loss = 0.000193
# Epoch 5, Overall loss = 0.000196

# %%
train(model, X_train[y_train==0], X_val[y_val==2], epochs=1,batch_size=32, reset_lp=0, reset_sp=0)
# Out:
# Iteration 0: with minibatch training loss = 0.000189
# Iteration 100: with minibatch training loss = 0.000186
# Epoch 1, Overall loss = 0.000196

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-4,1e-4],section=7, method="PC")

train(model, X_train[y_train==3], X_val[y_val==3], epochs=5,batch_size=32, reset_lp=0, reset_sp=0)
# Out:
# Iteration 0: with minibatch training loss = 0.00157
# Iteration 100: with minibatch training loss = 0.000236
# Epoch 1, Overall loss = 0.00026
# Iteration 200: with minibatch training loss = 0.000217
# Iteration 300: with minibatch training loss = 0.000215
# Epoch 2, Overall loss = 0.000211
# Iteration 400: with minibatch training loss = 0.000213
# Iteration 500: with minibatch training loss = 0.000205
# Epoch 3, Overall loss = 0.00021
# Iteration 600: with minibatch training loss = 0.000208
# Iteration 700: with minibatch training loss = 0.00021
# Epoch 4, Overall loss = 0.00021
# Iteration 800: with minibatch training loss = 0.000209
# Epoch 5, Overall loss = 0.00021

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[2e-3,2e-3],section=7, method="PC")

train(model, X_train[y_train==3], X_val[y_val==3], epochs=5,batch_size=32, reset_lp=1, reset_sp=1)
# Out:
# Iteration 0: with minibatch training loss = 0.00262
# Iteration 100: with minibatch training loss = 0.00141
# Epoch 1, Overall loss = 0.00151
# Iteration 200: with minibatch training loss = 0.000503
# Iteration 300: with minibatch training loss = 0.000444
# Epoch 2, Overall loss = 0.000463
# Iteration 400: with minibatch training loss = 0.000198
# Iteration 500: with minibatch training loss = 0.000199
# Epoch 3, Overall loss = 0.000194
# Iteration 600: with minibatch training loss = 0.000103
# Iteration 700: with minibatch training loss = 0.000104
# Epoch 4, Overall loss = 0.000109
# Iteration 800: with minibatch training loss = 8.01e-05
# Epoch 5, Overall loss = 8e-05

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-3,1e-3],section=7, method="PC")

train(model, X_train[y_train==2], X_val[y_val==2], epochs=5,batch_size=32, reset_lp=1, reset_sp=1)
# Out:
# Iteration 0: with minibatch training loss = 0.00208
# Iteration 100: with minibatch training loss = 0.00101
# Epoch 1, Overall loss = 0.00104
# Iteration 200: with minibatch training loss = 0.000359
# Iteration 300: with minibatch training loss = 0.000346
# Epoch 2, Overall loss = 0.000354
# Iteration 400: with minibatch training loss = 0.000156
# Iteration 500: with minibatch training loss = 0.000154
# Epoch 3, Overall loss = 0.000158
# Iteration 600: with minibatch training loss = 9.04e-05
# Epoch 4, Overall loss = 9.54e-05
# Iteration 700: with minibatch training loss = 7.37e-05
# Iteration 800: with minibatch training loss = 7.2e-05
# Epoch 5, Overall loss = 7.44e-05

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-3,1e-3],section=7, method="PC")

train(model, X_train[y_train==2], X_val[y_val==2], epochs=5,batch_size=32, reset_lp=1, reset_sp=1)
# Out:
# Iteration 0: with minibatch training loss = 0.00205
# Iteration 100: with minibatch training loss = 0.000969
# Epoch 1, Overall loss = 0.000996
# Iteration 200: with minibatch training loss = 0.000357
# Iteration 300: with minibatch training loss = 0.000315
# Epoch 2, Overall loss = 0.000337
# Iteration 400: with minibatch training loss = 0.000179
# Iteration 500: with minibatch training loss = 0.000181
# Epoch 3, Overall loss = 0.000172
# Iteration 600: with minibatch training loss = 0.000112
# Epoch 4, Overall loss = 0.000119
# Iteration 700: with minibatch training loss = 0.000114
# Iteration 800: with minibatch training loss = 9.84e-05
# Epoch 5, Overall loss = 9.7e-05

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-3,1e-3],section=7, method="PC")

train(model, X_train[y_train==4], X_val[y_val==4], epochs=5,batch_size=32,reset_lp=1,reset_sp=1)
# Out:
# Iteration 0: with minibatch training loss = 0.00165
# Iteration 100: with minibatch training loss = 0.000882
# Epoch 1, Overall loss = 0.000913
# Iteration 200: with minibatch training loss = 0.000266
# Iteration 300: with minibatch training loss = 0.000255
# Epoch 2, Overall loss = 0.000264
# Iteration 400: with minibatch training loss = 0.000106
# Iteration 500: with minibatch training loss = 0.000106
# Epoch 3, Overall loss = 0.000111
# Iteration 600: with minibatch training loss = 6.82e-05
# Epoch 4, Overall loss = 6.79e-05
# Iteration 700: with minibatch training loss = 5.36e-05
# Iteration 800: with minibatch training loss = 6.26e-05
# Epoch 5, Overall loss = 5.43e-05

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-3,1e-3],section=7, method="PC")

train(model, X_train[y_train==9], X_val[y_val==9], epochs=5,batch_size=32,reset_lp=1,reset_sp=1)
# Out:
# Iteration 0: with minibatch training loss = 0.00171
# Iteration 100: with minibatch training loss = 0.000921
# Epoch 1, Overall loss = 0.000933
# Iteration 200: with minibatch training loss = 0.000294
# Iteration 300: with minibatch training loss = 0.000257
# Epoch 2, Overall loss = 0.000276
# Iteration 400: with minibatch training loss = 0.00011
# Iteration 500: with minibatch training loss = 0.000105
# Epoch 3, Overall loss = 0.000114
# Iteration 600: with minibatch training loss = 6.87e-05
# Epoch 4, Overall loss = 6.77e-05
# Iteration 700: with minibatch training loss = 5.41e-05
# Iteration 800: with minibatch training loss = 4.63e-05
# Epoch 5, Overall loss = 5.28e-05

# %%
keras.backend.clear_session()
try:
    del model
except:pass
model = curve2D(num_points=20, learning_rate=1e-3,
                lambs=[1e-3,1e-3],section=7, method="Wass")

train(model, X_train[y_train==9], X_val[y_val==9], epochs=5,batch_size=32,reset_lp=5,reset_sp=5)
# Out:
# Iteration 0: with minibatch training loss = 0.0512
# Iteration 100: with minibatch training loss = 0.0426
# Epoch 1, Overall loss = 0.0441
# Iteration 200: with minibatch training loss = 0.0445
# Iteration 300: with minibatch training loss = 0.0451
# Epoch 2, Overall loss = 0.0448
# Iteration 400: with minibatch training loss = 0.0347
# Iteration 500: with minibatch training loss = 0.0328
# Epoch 3, Overall loss = 0.0332
# Iteration 600: with minibatch training loss = 0.0209
# Epoch 4, Overall loss = 0.0218
# Iteration 700: with minibatch training loss = 0.0172
# Iteration 800: with minibatch training loss = 0.0173
# Epoch 5, Overall loss = 0.0171
